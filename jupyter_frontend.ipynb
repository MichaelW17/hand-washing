# %%
import sys
from PyQt5.QtCore import *
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
from PyQt5.QtGui import *
import numpy as np
from backend import Washer  # 后端处理

import cgitb
cgitb.enable(format='text')  # 显示多线程错误信息
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From c:\users\minghao\anaconda3\envs\tf36\lib\site-packages\tensorflow\python\framework\function.py:987: calling Graph.create_op (from tensorflow.python.framework.ops) with compute_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Shapes are always computed; don't use the compute_shapes as it has no effect.

# %%
# 全局变量
PAUSE = 0

# 将图像处理工作放在一个QObject子类中完成，用于QThread多线程实现
class Worker(QObject):

    call_todo = pyqtSignal(str)  # 用于触发worker的后台运行
    trigger = pyqtSignal()  # 每处理完一帧触发显示
    clear = pyqtSignal()    # 触发清空输入缓存的信号

    def __init__(self):
        super().__init__()
        self.washing_time = 0
        self.frame_to_show = np.zeros((1024, 576, 3), dtype=np.uint8)

    @pyqtSlot(str)  # 使signal-slot的绑定关系与moveToThread的先后顺序无关
    def start(self, video_name):
        print('subthread ID: ', int(QThread.currentThreadId()))  # 打印子线程号
        lil_washer = Washer(video_path=video_name)
        self.frame_to_show = np.zeros((1024, 576, 3), dtype=np.uint8)
        self.washing_time = 0  # 洗手总计时间(1/24×帧数，单位为s)
        self.video_end = 0
        # VIDEO_PATH = 'C:/Users/Minghao/Desktop/gopro1/TEST1.MP4'
        while 1:
            # 07/24/2019: 将状态机的flag信号添加到输出列表中:self.machine_state，目的是确保flag=0的时候才能确认付款
            if PAUSE == 1:
                pass
            elif PAUSE == -1:
                lil_washer.video_cap.release()
                break
            elif PAUSE == 0:
                self.frame_to_show, self.washing_time, self.video_end = lil_washer.predict()
                self.trigger.emit()
                if self.video_end:  # 视频播放到了最后一帧
                    self.video_end = 0
                    self.clear.emit()

# %%
class FrontEnd(QWidget):

    def __init__(self):
        super().__init__()
        self.video_name = 'C:/Users/Minghao/Desktop/gopro1/TEST1.MP4'
        self.initUI()

    def initUI(self):
        # 为图像处理建立后台线程
        self.workThread = QThread()
        self.workThread.start()
        self.worker = Worker()  # 例化一个worker对象
        self.worker.moveToThread(self.workThread)
        self.worker.trigger.connect(self.showFrame)  # 每处理完一帧，打印
        self.worker.clear.connect(self.restart)
        self.worker.call_todo.connect(self.worker.start)

        # 以下是控件及其功能设计
        # 获取显示器分辨率
        self.desktop = QApplication.desktop()
        self.screenRect = self.desktop.screenGeometry()
        self.width = self.screenRect.width()  # 屏幕宽度
        self.height = self.screenRect.height()  # 屏幕高度

        # self.setGeometry(int(self.width/4), int(self.height/4), int(self.width/4*9/16), int(self.height/4*16/9))  # 窗口初始大小为屏幕的1/4
        # self.setMinimumSize(1280, 720)
#         self.setGeometry(300, 300, 1200, 700)
        self.setWindowTitle("洗手检测demo")

        self.label_show_image = QLabel()  # 显示摄像头画面的控件，DragLabel是继承自QLabel的自定义类，实现了鼠标选区功能
        self.label_show_image.setFixedSize(1024, 576)

        self.loadVideoButton = QPushButton("视频输入")
        # self.loadVideoButton.setText(u"选择视频")
        self.loadVideoButton.clicked.connect(self.loadVideo)
        self.loadVideoButton.setFixedSize(400, 50)

        self.startButton = QPushButton("开始检测")
        self.startButton.clicked.connect(self.work)
        self.startButton.setCheckable(True)  # 设为可以按下和弹起的形式
        self.startButton.setFixedSize(400, 50)

        # 进度条和刷新进度条用的计时器
        self.pbar = QProgressBar()
        self.pbar.setRange(0, 10)
        self.pbar.setFixedSize(900, 50)
        self.timer = QBasicTimer()
        self.timer.start(100, self)


        # 控件布局设计：QGridLayout
        main_layout = QGridLayout(self)  # 整体使用网格布局
        main_layout.addWidget(self.label_show_image, 0, 0, 9, 16)
        main_layout.addWidget(self.loadVideoButton, 9, 0, 2, 8)
        main_layout.addWidget(self.startButton, 9, 9, 2, 8)
        main_layout.addWidget(self.pbar, 11, 0, 2, 16)
        main_layout.setAlignment(Qt.AlignCenter)
        self.setLayout(main_layout)

        self.showFrame()

        # 设置整个窗口的背景颜色为白色而不是默认的灰色
        bgColor = QPalette()
        bgColor.setColor(self.backgroundRole(), QColor(255, 255, 255))
        self.setPalette(bgColor)

    # 重写QObject的timerEvent方法，用于刷新显示进度条
    def timerEvent(self, event):
        if self.worker.washing_time >= 10:
            self.time = 10
        else:
            self.time = self.worker.washing_time
        self.pbar.setValue(self.time)
        self.pbar.update()


    def loadVideo(self):
         video_name = QFileDialog.getOpenFileName(self, caption="open file dialog", directory="C:/Users/Minghao/Desktop/gopro")
         self.video_name = video_name[0]

    def keyPressEvent(self, keyEvent):
        global PAUSE
        if keyEvent.key() == Qt.Key_Escape:
            print(keyEvent.key())
            self.close()
        elif keyEvent.key() == Qt.Key_P:  # 按下P键暂停/继续
            PAUSE = PAUSE ^ 1
        elif keyEvent.key() == Qt.Key_Q:  # 按下Q键停止当前视频
            PAUSE = -1

    # 第一个按钮：开始结账/确认付款
    def work(self):
        global PAUSE
        PAUSE = 0
        self.worker.call_todo.emit(self.video_name)


    def showFrame(self):
        self.label_show_image.setScaledContents(True)
        IMG = self.worker.frame_to_show
        frame_height, frame_width, channel = IMG.shape
        bytesPerline = 3 * frame_width
        img = QImage(IMG.data, frame_width, frame_height, bytesPerline,
                     QImage.Format_RGB888).rgbSwapped()
        # 根据宽高比设置待显示图像的尺寸（使用QImage的scaled方法）
        widget_width = self.label_show_image.width()
        widget_height = self.label_show_image.height()
        frame_ratio = float(frame_width) / float(frame_height)
        widget_ratio = float(widget_width) / float(widget_height)
        if frame_ratio <= widget_ratio:
            adjusted_height = widget_height
            adjusted_width = int(widget_height * frame_ratio)
        else:  # frame_ratio >= widget_ratio
            adjusted_width = widget_width
            adjusted_height = int(widget_width / frame_ratio)
        img = QPixmap.fromImage(img).scaled(adjusted_width, adjusted_height)
        self.label_show_image.setPixmap(img)



    def restart(self):  # 当前视频播放完毕，重播一遍
        # 如果本次扫码失败,弹出对话框进行提示
        self.worker.call_todo.emit(self.video_name)

# %%
if __name__ == "__main__":
    print('parent thread ID: ', int(QThread.currentThreadId()))  # 打印主线程ID
    app = QApplication(sys.argv)
    example = FrontEnd()
    example.show()
    sys.exit(app.exec_())
# Out:
# parent thread ID:  28192
# subthread ID:  860
# frame ID:  1
# frame ID:  2
# frame ID:  3
# frame ID:  4
# frame ID:  5
# frame ID:  6
# frame ID:  7
# frame ID:  8
# frame ID:  9
# frame ID:  10
# frame ID:  11
# frame ID:  12
# frame ID:  19
# frame ID:  20
# frame ID:  21
# frame ID:  22
# frame ID:  23
# frame ID:  24
# frame ID:  25
# frame ID:  26
# frame ID:  27
# frame ID:  28
# frame ID:  29
# frame ID:  30
# frame ID:  31
# frame ID:  32
# frame ID:  33
# frame ID:  34
# frame ID:  35
# frame ID:  36
# frame ID:  37
# frame ID:  38
# frame ID:  39
# frame ID:  40
# frame ID:  41
# frame ID:  42
# frame ID:  43
# frame ID:  44
# frame ID:  45
# frame ID:  46
# frame ID:  47
# frame ID:  48
# frame ID:  49
# frame ID:  50
# frame ID:  51
# frame ID:  52
# frame ID:  53
# frame ID:  54
# frame ID:  55
# frame ID:  56
# frame ID:  57
# frame ID:  58
# frame ID:  59
# frame ID:  60
# frame ID:  61
# frame ID:  62
# frame ID:  63
# frame ID:  64
# frame ID:  65
# frame ID:  66
# frame ID:  67
# frame ID:  68
# frame ID:  69
# frame ID:  70
# frame ID:  71
# frame ID:  72
# frame ID:  73
# frame ID:  74
# frame ID:  75
# frame ID:  76
# frame ID:  77
# frame ID:  78
# frame ID:  79
# frame ID:  80
# frame ID:  81
# frame ID:  82
# frame ID:  83
# frame ID:  84
# frame ID:  85
# frame ID:  86
# frame ID:  87
# frame ID:  88
# frame ID:  89
# frame ID:  90
# frame ID:  91
# frame ID:  92
# frame ID:  93
# frame ID:  94
# frame ID:  95
# frame ID:  96
# frame ID:  97
# frame ID:  98
# frame ID:  99
# frame ID:  100
# frame ID:  101
# frame ID:  102
# frame ID:  103
# frame ID:  104
# frame ID:  105
# frame ID:  106
# frame ID:  107
# frame ID:  108
# frame ID:  109
# frame ID:  110
# frame ID:  111
# frame ID:  112
# frame ID:  113
# frame ID:  114
# frame ID:  115
# frame ID:  116
# frame ID:  117
# frame ID:  118
# frame ID:  119
# frame ID:  120
# washing time:  0.041666666666666664
# frame ID:  121
# washing time:  0.08333333333333333
# frame ID:  122
# washing time:  0.125
# frame ID:  123
# washing time:  0.16666666666666666
# frame ID:  124
# washing time:  0.20833333333333331
# frame ID:  125
# washing time:  0.24999999999999997
# frame ID:  126
# washing time:  0.29166666666666663
# frame ID:  127
# washing time:  0.3333333333333333
# frame ID:  128
# washing time:  0.375
# frame ID:  129
# washing time:  0.4166666666666667
# frame ID:  130
# washing time:  0.45833333333333337
# frame ID:  131
# washing time:  0.5
# frame ID:  132
# washing time:  0.5416666666666666
# frame ID:  133
# washing time:  0.5833333333333333
# frame ID:  134
# washing time:  0.6249999999999999
# frame ID:  135
# washing time:  0.6666666666666665
# frame ID:  136
# washing time:  0.7083333333333331
# frame ID:  137
# washing time:  0.7499999999999998
# frame ID:  138
# washing time:  0.7916666666666664
# frame ID:  139
# washing time:  0.833333333333333
# frame ID:  140
# washing time:  0.8749999999999997
# frame ID:  141
# washing time:  0.9166666666666663
# frame ID:  142
# washing time:  0.9583333333333329
# frame ID:  143
# washing time:  0.9999999999999996
# frame ID:  144
# washing time:  1.0416666666666663
# frame ID:  145
# washing time:  1.083333333333333
# frame ID:  146
# washing time:  1.1249999999999998
# frame ID:  147
# washing time:  1.1666666666666665
# frame ID:  148
# washing time:  1.2083333333333333
# frame ID:  149
# washing time:  1.25
# frame ID:  150
# washing time:  1.2916666666666667
# frame ID:  151
# frame ID:  152
# washing time:  1.3333333333333335
# frame ID:  153
# washing time:  1.3750000000000002
# frame ID:  154
# washing time:  1.416666666666667
# frame ID:  155
# washing time:  1.4583333333333337
# frame ID:  156
# washing time:  1.5000000000000004
# frame ID:  157
# washing time:  1.5416666666666672
# frame ID:  158
# washing time:  1.583333333333334
# frame ID:  159
# washing time:  1.6250000000000007
# frame ID:  160
# washing time:  1.6666666666666674
# frame ID:  161
# washing time:  1.7083333333333341
# frame ID:  162
# washing time:  1.7500000000000009
# frame ID:  163
# washing time:  1.7916666666666676
# frame ID:  164
# washing time:  1.8333333333333344
# frame ID:  165
# washing time:  1.875000000000001
# frame ID:  166
# washing time:  1.9166666666666679
# frame ID:  167
# washing time:  1.9583333333333346
# frame ID:  168
# washing time:  2.0000000000000013
# frame ID:  169
# washing time:  2.041666666666668
# frame ID:  170
# washing time:  2.0833333333333344
# frame ID:  171
# washing time:  2.125000000000001
# frame ID:  172
# washing time:  2.1666666666666674
# frame ID:  173
# washing time:  2.208333333333334
# frame ID:  174
# washing time:  2.2500000000000004
# frame ID:  175
# washing time:  2.291666666666667
# frame ID:  176
# washing time:  2.3333333333333335
# frame ID:  177
# washing time:  2.375
# frame ID:  178
# washing time:  2.4166666666666665
# frame ID:  179
# washing time:  2.458333333333333
# frame ID:  180
# washing time:  2.4999999999999996
# frame ID:  181
# washing time:  2.541666666666666
# frame ID:  182
# washing time:  2.5833333333333326
# frame ID:  183
# washing time:  2.624999999999999
# frame ID:  184
# washing time:  2.6666666666666656
# frame ID:  185
# washing time:  2.708333333333332
# frame ID:  186
# washing time:  2.7499999999999987
# frame ID:  187
# washing time:  2.791666666666665
# frame ID:  188
# washing time:  2.8333333333333317
# frame ID:  189
# washing time:  2.8749999999999982
# frame ID:  190
# washing time:  2.9166666666666647
# frame ID:  191
# washing time:  2.9583333333333313
# frame ID:  192
# washing time:  2.999999999999998
# frame ID:  193
# washing time:  3.0416666666666643
# frame ID:  194
# washing time:  3.083333333333331
# frame ID:  195
# washing time:  3.1249999999999973
# frame ID:  196
# washing time:  3.166666666666664
# frame ID:  197
# washing time:  3.2083333333333304
# frame ID:  198
# washing time:  3.249999999999997
# frame ID:  199
# washing time:  3.2916666666666634
# frame ID:  200
# washing time:  3.33333333333333
# frame ID:  201
# washing time:  3.3749999999999964
# frame ID:  202
# washing time:  3.416666666666663
# frame ID:  203
# washing time:  3.4583333333333295
# frame ID:  204
# washing time:  3.499999999999996
# frame ID:  205
# washing time:  3.5416666666666625
# frame ID:  206
# washing time:  3.583333333333329
# frame ID:  207
# washing time:  3.6249999999999956
# frame ID:  208
# washing time:  3.666666666666662
# frame ID:  209
# washing time:  3.7083333333333286
# frame ID:  210
# washing time:  3.749999999999995
# frame ID:  211
# washing time:  3.7916666666666616
# frame ID:  212
# washing time:  3.833333333333328
# frame ID:  213
# washing time:  3.8749999999999947
# frame ID:  214
# washing time:  3.916666666666661
# frame ID:  215
# washing time:  3.9583333333333277
# frame ID:  216
# washing time:  3.9999999999999942
# frame ID:  217
# washing time:  4.041666666666661
# frame ID:  218
# washing time:  4.083333333333328
# frame ID:  219
# washing time:  4.124999999999995
# frame ID:  220
# washing time:  4.166666666666662
# frame ID:  221
# washing time:  4.208333333333329
# frame ID:  222
# washing time:  4.249999999999996
# frame ID:  223
# washing time:  4.2916666666666625
# frame ID:  224
# washing time:  4.3333333333333295
# frame ID:  225
# washing time:  4.3749999999999964
# frame ID:  226
# washing time:  4.416666666666663
# frame ID:  227
# washing time:  4.45833333333333
# frame ID:  228
# washing time:  4.499999999999997
# frame ID:  229
# washing time:  4.541666666666664
# frame ID:  230
# washing time:  4.583333333333331
# frame ID:  231
# washing time:  4.624999999999998
# frame ID:  232
# washing time:  4.666666666666665
# frame ID:  233
# washing time:  4.708333333333332
# frame ID:  234
# washing time:  4.749999999999999
# frame ID:  235
# washing time:  4.791666666666666
# frame ID:  236
# washing time:  4.833333333333333
# frame ID:  237
# washing time:  4.875
# frame ID:  238
# washing time:  4.916666666666667
# frame ID:  239
# washing time:  4.958333333333334
# frame ID:  240
# washing time:  5.000000000000001
# frame ID:  241
# washing time:  5.041666666666668
# frame ID:  242
# washing time:  5.083333333333335
# frame ID:  243
# washing time:  5.125000000000002
# frame ID:  244
# washing time:  5.166666666666669
# frame ID:  245
# washing time:  5.208333333333336
# frame ID:  246
# washing time:  5.250000000000003
# frame ID:  247
# washing time:  5.29166666666667
# frame ID:  248
# washing time:  5.333333333333337
# frame ID:  249
# washing time:  5.3750000000000036
# frame ID:  250
# washing time:  5.4166666666666705
# frame ID:  251
# washing time:  5.4583333333333375
# frame ID:  252
# washing time:  5.500000000000004
# frame ID:  253
# washing time:  5.541666666666671
# frame ID:  254
# washing time:  5.583333333333338
# frame ID:  255
# washing time:  5.625000000000005
# frame ID:  256
# washing time:  5.666666666666672
# frame ID:  257
# washing time:  5.708333333333339
# frame ID:  258
# washing time:  5.750000000000006
# frame ID:  259
# washing time:  5.791666666666673
# frame ID:  260
# washing time:  5.83333333333334
# frame ID:  261
# washing time:  5.875000000000007
# frame ID:  262
# washing time:  5.916666666666674
# frame ID:  263
# washing time:  5.958333333333341
# frame ID:  264
# washing time:  6.000000000000008
# frame ID:  265
# washing time:  6.041666666666675
# frame ID:  266
# washing time:  6.083333333333342
# frame ID:  267
# washing time:  6.125000000000009
# frame ID:  268
# washing time:  6.166666666666676
# frame ID:  269
# washing time:  6.208333333333343
# frame ID:  270
# washing time:  6.25000000000001
# frame ID:  271
# washing time:  6.291666666666677
# frame ID:  272
# washing time:  6.333333333333344
# frame ID:  273
# washing time:  6.375000000000011
# frame ID:  274
# washing time:  6.416666666666678
# frame ID:  275
# washing time:  6.458333333333345
# frame ID:  276
# washing time:  6.5000000000000115
# frame ID:  277
# washing time:  6.5416666666666785
# frame ID:  278
# washing time:  6.5833333333333455
# frame ID:  279
# washing time:  6.625000000000012
# frame ID:  280
# washing time:  6.666666666666679
# frame ID:  281
# washing time:  6.708333333333346
# frame ID:  282
# washing time:  6.750000000000013
# frame ID:  283
# washing time:  6.79166666666668
# frame ID:  284
# washing time:  6.833333333333347
# frame ID:  285
# washing time:  6.875000000000014
# frame ID:  286
# washing time:  6.916666666666681
# frame ID:  287
# washing time:  6.958333333333348
# frame ID:  288
# washing time:  7.000000000000015
# frame ID:  289
# washing time:  7.041666666666682
# frame ID:  290
# washing time:  7.083333333333349
# frame ID:  291
# washing time:  7.125000000000016
# frame ID:  292
# washing time:  7.166666666666683
# frame ID:  293
# washing time:  7.20833333333335
# frame ID:  294
# washing time:  7.250000000000017
# frame ID:  295
# washing time:  7.291666666666684
# frame ID:  296
# washing time:  7.333333333333351
# frame ID:  297
# washing time:  7.375000000000018
# frame ID:  298
# washing time:  7.416666666666685
# frame ID:  299
# washing time:  7.458333333333352
# frame ID:  300
# washing time:  7.500000000000019
# frame ID:  301
# washing time:  7.541666666666686
# frame ID:  302
# washing time:  7.583333333333353
# frame ID:  303
# washing time:  7.6250000000000195
# frame ID:  304
# washing time:  7.6666666666666865
# frame ID:  305
# washing time:  7.7083333333333535
# frame ID:  306
# washing time:  7.75000000000002
# frame ID:  307
# washing time:  7.791666666666687
# frame ID:  308
# washing time:  7.833333333333354
# frame ID:  309
# washing time:  7.875000000000021
# frame ID:  310
# washing time:  7.916666666666688
# frame ID:  311
# washing time:  7.958333333333355
# frame ID:  312
# washing time:  8.000000000000021
# frame ID:  313
# washing time:  8.041666666666687
# frame ID:  314
# washing time:  8.083333333333353
# frame ID:  315
# washing time:  8.12500000000002
# frame ID:  316
# washing time:  8.166666666666686
# frame ID:  317
# washing time:  8.208333333333352
# frame ID:  318
# washing time:  8.250000000000018
# frame ID:  319
# washing time:  8.291666666666684
# frame ID:  320
# washing time:  8.33333333333335
# frame ID:  321
# washing time:  8.375000000000016
# frame ID:  322
# washing time:  8.416666666666682
# frame ID:  323
# washing time:  8.458333333333348
# frame ID:  324
# washing time:  8.500000000000014
# frame ID:  325
# washing time:  8.54166666666668
# frame ID:  326
# washing time:  8.583333333333346
# frame ID:  327
# washing time:  8.625000000000012
# frame ID:  328
# washing time:  8.666666666666679
# frame ID:  329
# washing time:  8.708333333333345
# frame ID:  330
# washing time:  8.75000000000001
# frame ID:  331
# washing time:  8.791666666666677
# frame ID:  332
# washing time:  8.833333333333343
# frame ID:  333
# washing time:  8.875000000000009
# frame ID:  334
# washing time:  8.916666666666675
# frame ID:  335
# washing time:  8.958333333333341
# frame ID:  336
# washing time:  9.000000000000007
# frame ID:  337
# washing time:  9.041666666666673
# frame ID:  338
# washing time:  9.08333333333334
# frame ID:  339
# washing time:  9.125000000000005
# frame ID:  340
# washing time:  9.166666666666671
# frame ID:  341
# washing time:  9.208333333333337
# frame ID:  342
# washing time:  9.250000000000004
# frame ID:  343
# washing time:  9.29166666666667
# frame ID:  344
# washing time:  9.333333333333336
# frame ID:  345
# washing time:  9.375000000000002
# frame ID:  346
# washing time:  9.416666666666668
# frame ID:  347
# washing time:  9.458333333333334
# frame ID:  348
# washing time:  9.5
# frame ID:  349
# washing time:  9.541666666666666
# frame ID:  350
# washing time:  9.583333333333332
# frame ID:  351
# washing time:  9.624999999999998
# frame ID:  352
# washing time:  9.666666666666664
# frame ID:  353
# washing time:  9.70833333333333
# frame ID:  354
# washing time:  9.749999999999996
# frame ID:  355
# washing time:  9.791666666666663
# frame ID:  356
# washing time:  9.833333333333329
# frame ID:  357
# washing time:  9.874999999999995
# frame ID:  358
# washing time:  9.91666666666666
# frame ID:  359
# washing time:  9.958333333333327
# frame ID:  360
# 16777216
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\users\minghao\anaconda3\envs\tf36\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
# washing time:  9.999999999999993
# frame ID:  361
# washing time:  10.041666666666659
# frame ID:  362
# washing time:  10.083333333333325
# frame ID:  363
# washing time:  10.124999999999991
# frame ID:  364
# washing time:  10.166666666666657
# frame ID:  365
# washing time:  10.208333333333323
# frame ID:  366
# washing time:  10.24999999999999
# frame ID:  367
# washing time:  10.291666666666655
# frame ID:  368
# washing time:  10.333333333333321
# frame ID:  369
# washing time:  10.374999999999988
# frame ID:  370
# washing time:  10.416666666666654
# frame ID:  371
# washing time:  10.45833333333332
# frame ID:  372
# washing time:  10.499999999999986
# frame ID:  373
# washing time:  10.541666666666652
# frame ID:  374
# washing time:  10.583333333333318
# frame ID:  375
# washing time:  10.624999999999984
# frame ID:  376
# washing time:  10.66666666666665
# frame ID:  377
# washing time:  10.708333333333316
# frame ID:  378
# washing time:  10.749999999999982
# frame ID:  379
# washing time:  10.791666666666648
# frame ID:  380
# washing time:  10.833333333333314
# frame ID:  381
# washing time:  10.87499999999998
# frame ID:  382
# washing time:  10.916666666666647
# frame ID:  383
# washing time:  10.958333333333313
# frame ID:  384
# washing time:  10.999999999999979
# frame ID:  385
# washing time:  11.041666666666645
# frame ID:  386
# washing time:  11.08333333333331
# frame ID:  387
# washing time:  11.124999999999977
# frame ID:  388
# washing time:  11.166666666666643
# frame ID:  389
# washing time:  11.208333333333309
# frame ID:  390
# washing time:  11.249999999999975
# frame ID:  391
# washing time:  11.291666666666641
# frame ID:  392
# washing time:  11.333333333333307
# frame ID:  393
# washing time:  11.374999999999973
# frame ID:  394
# washing time:  11.41666666666664
# frame ID:  395
# washing time:  11.458333333333306
# frame ID:  396
# washing time:  11.499999999999972
# frame ID:  397
# frame ID:  398
# frame ID:  399
# frame ID:  400
# frame ID:  401
# frame ID:  402
# frame ID:  403
# frame ID:  404
# frame ID:  405
# frame ID:  406
# frame ID:  407
# frame ID:  408
# frame ID:  409
# frame ID:  410
# frame ID:  411
# frame ID:  412
# frame ID:  413
# frame ID:  414
# frame ID:  415
# frame ID:  416
# frame ID:  417
# frame ID:  418
# frame ID:  419
# frame ID:  420
# frame ID:  421
# frame ID:  422
# frame ID:  423
# frame ID:  424
# frame ID:  425
# frame ID:  426
# frame ID:  427
# frame ID:  428
# frame ID:  429
# frame ID:  430
# frame ID:  431
# frame ID:  432
# frame ID:  433
# frame ID:  434
# frame ID:  435
# frame ID:  436
# frame ID:  437
# frame ID:  438
# frame ID:  439
# frame ID:  440
# frame ID:  441
# frame ID:  442
# frame ID:  443
# frame ID:  444
# frame ID:  445
# frame ID:  446
# frame ID:  447
# frame ID:  448
# frame ID:  449
# frame ID:  450
# frame ID:  451
# frame ID:  452
# frame ID:  453
# frame ID:  454
# frame ID:  455
# frame ID:  456
# frame ID:  457
# frame ID:  458
# frame ID:  459
# frame ID:  460
# frame ID:  461
# frame ID:  462
# frame ID:  463
# frame ID:  464
# frame ID:  465
# frame ID:  466
# frame ID:  467
# frame ID:  468
# frame ID:  469
# frame ID:  470
# frame ID:  471
# frame ID:  472
# frame ID:  473
# frame ID:  474
# frame ID:  475
# frame ID:  476
# frame ID:  477
# frame ID:  478
# frame ID:  479
# frame ID:  480
# frame ID:  481
# frame ID:  482
# frame ID:  483
# frame ID:  484
# washing time:  11.541666666666638
# frame ID:  485
# washing time:  11.583333333333304
# frame ID:  486
# washing time:  11.62499999999997
# frame ID:  487
# washing time:  11.666666666666636
# frame ID:  488
# washing time:  11.708333333333302
# frame ID:  489
# washing time:  11.749999999999968
# frame ID:  490
# washing time:  11.791666666666634
# frame ID:  491
# washing time:  11.8333333333333
# frame ID:  492
# washing time:  11.874999999999966
# frame ID:  493
# washing time:  11.916666666666632
# frame ID:  494
# washing time:  11.958333333333298
# frame ID:  495
# washing time:  11.999999999999964
# frame ID:  496
# washing time:  12.04166666666663
# frame ID:  497
# washing time:  12.083333333333297
# frame ID:  498
# washing time:  12.124999999999963
# frame ID:  499
# washing time:  12.166666666666629
# frame ID:  500
# washing time:  12.208333333333295
# frame ID:  501
# washing time:  12.249999999999961
# frame ID:  502
# washing time:  12.291666666666627
# frame ID:  503
# washing time:  12.333333333333293
# frame ID:  504
# washing time:  12.37499999999996
# frame ID:  505
# washing time:  12.416666666666625
# frame ID:  506
# washing time:  12.458333333333291
# frame ID:  507
# washing time:  12.499999999999957
# frame ID:  508
# washing time:  12.541666666666623
# frame ID:  509
# washing time:  12.58333333333329
# frame ID:  510
# washing time:  12.624999999999956
# frame ID:  511
# washing time:  12.666666666666622
# frame ID:  512
# washing time:  12.708333333333288
# frame ID:  513
# washing time:  12.749999999999954
# frame ID:  514
# washing time:  12.79166666666662
# frame ID:  515
# washing time:  12.833333333333286
# frame ID:  516
# washing time:  12.874999999999952
# frame ID:  517
# washing time:  12.916666666666618
# frame ID:  518
# washing time:  12.958333333333284
# frame ID:  519
# washing time:  12.99999999999995
# frame ID:  520
# washing time:  13.041666666666616
# frame ID:  521
# washing time:  13.083333333333282
# frame ID:  522
# washing time:  13.124999999999948
# frame ID:  523
# washing time:  13.166666666666615
# frame ID:  524
# washing time:  13.20833333333328
# frame ID:  525
# washing time:  13.249999999999947
# frame ID:  526
# washing time:  13.291666666666613
# frame ID:  527
# washing time:  13.333333333333279
# frame ID:  528
# washing time:  13.374999999999945
# frame ID:  529
# washing time:  13.416666666666611
# frame ID:  530
# washing time:  13.458333333333277
# frame ID:  531
# washing time:  13.499999999999943
# frame ID:  532
# washing time:  13.54166666666661
# frame ID:  533
# washing time:  13.583333333333275
# frame ID:  534
# washing time:  13.624999999999941
# frame ID:  535
# washing time:  13.666666666666607
# frame ID:  536
# washing time:  13.708333333333274
# frame ID:  537
# washing time:  13.74999999999994
# frame ID:  538
# washing time:  13.791666666666606
# frame ID:  539
# washing time:  13.833333333333272
# frame ID:  540
# washing time:  13.874999999999938
# frame ID:  541
# washing time:  13.916666666666604
# frame ID:  542
# washing time:  13.95833333333327
# frame ID:  543
# washing time:  13.999999999999936
# frame ID:  544
# washing time:  14.041666666666602
# frame ID:  545
# washing time:  14.083333333333268
# frame ID:  546
# washing time:  14.124999999999934
# frame ID:  547
# washing time:  14.1666666666666
# frame ID:  548
# washing time:  14.208333333333266
# frame ID:  549
# washing time:  14.249999999999932
# frame ID:  550
# washing time:  14.291666666666599
# frame ID:  551
# washing time:  14.333333333333265
# frame ID:  552
# washing time:  14.37499999999993
# frame ID:  553
# washing time:  14.416666666666597
# frame ID:  554
# washing time:  14.458333333333263
# frame ID:  555
# washing time:  14.499999999999929
# frame ID:  556
# washing time:  14.541666666666595
# frame ID:  557
# washing time:  14.583333333333261
# frame ID:  558
# washing time:  14.624999999999927
# frame ID:  559
# washing time:  14.666666666666593
# frame ID:  560
# washing time:  14.70833333333326
# frame ID:  561
# washing time:  14.749999999999925
# frame ID:  562
# washing time:  14.791666666666591
# frame ID:  563
# washing time:  14.833333333333258
# frame ID:  564
# washing time:  14.874999999999924
# frame ID:  565
# washing time:  14.91666666666659
# frame ID:  566
# washing time:  14.958333333333256
# frame ID:  567
# washing time:  14.999999999999922
# frame ID:  568
# washing time:  15.041666666666588
# frame ID:  569
# washing time:  15.083333333333254
# frame ID:  570
# washing time:  15.12499999999992
# frame ID:  571
# frame ID:  572
# washing time:  15.166666666666586
# frame ID:  573
# washing time:  15.208333333333252
# frame ID:  574
# washing time:  15.249999999999918
# frame ID:  575
# washing time:  15.291666666666584
# frame ID:  576
# washing time:  15.33333333333325
# frame ID:  577
# washing time:  15.374999999999917
# frame ID:  578
# washing time:  15.416666666666583
# frame ID:  579
# washing time:  15.458333333333249
# frame ID:  580
# washing time:  15.499999999999915
# frame ID:  581
# washing time:  15.54166666666658
# frame ID:  582
# washing time:  15.583333333333247
# frame ID:  583
# washing time:  15.624999999999913
# frame ID:  584
# washing time:  15.666666666666579
# frame ID:  585
# washing time:  15.708333333333245
# frame ID:  586
# washing time:  15.749999999999911
# frame ID:  587
# washing time:  15.791666666666577
# frame ID:  588
# washing time:  15.833333333333243
# frame ID:  589
# washing time:  15.87499999999991
# frame ID:  590
# washing time:  15.916666666666575
# frame ID:  591
# washing time:  15.958333333333242
# frame ID:  592
# washing time:  15.999999999999908
# frame ID:  593
# washing time:  16.041666666666575
# frame ID:  594
# washing time:  16.083333333333243
# frame ID:  595
# washing time:  16.12499999999991
# frame ID:  596
# washing time:  16.16666666666658
# frame ID:  597
# washing time:  16.208333333333247
# frame ID:  598
# washing time:  16.249999999999915
# frame ID:  599
# washing time:  16.291666666666583
# frame ID:  600
# washing time:  16.33333333333325
# frame ID:  601
# washing time:  16.37499999999992
# frame ID:  602
# washing time:  16.416666666666586
# frame ID:  603
# washing time:  16.458333333333254
# frame ID:  604
# washing time:  16.499999999999922
# frame ID:  605
# washing time:  16.54166666666659
# frame ID:  606
# washing time:  16.583333333333258
# frame ID:  607
# frame ID:  608
# frame ID:  609
# frame ID:  610
# frame ID:  611
# frame ID:  612
# frame ID:  613
# frame ID:  614
# frame ID:  615
# frame ID:  616
# frame ID:  617
# frame ID:  618
# frame ID:  619
# frame ID:  620
# frame ID:  621
# frame ID:  622
# frame ID:  623
# frame ID:  624
# frame ID:  625
# frame ID:  626
# frame ID:  627
# frame ID:  628
# frame ID:  629
# frame ID:  630
# frame ID:  631
# frame ID:  632
# frame ID:  633
# frame ID:  634
# frame ID:  635
# frame ID:  636
# frame ID:  637
# frame ID:  638
# frame ID:  639
# frame ID:  640
# frame ID:  641
# frame ID:  642
# frame ID:  643
# frame ID:  644
# frame ID:  645
# frame ID:  646
# frame ID:  647
# frame ID:  648
# frame ID:  649
# frame ID:  650
# frame ID:  651
# frame ID:  652
# frame ID:  653
# frame ID:  654
# frame ID:  655
# frame ID:  656
# frame ID:  657
# frame ID:  658
# frame ID:  659
# frame ID:  660
# frame ID:  661
# frame ID:  662
# frame ID:  663
# frame ID:  664
# frame ID:  665
# frame ID:  666
# frame ID:  667
# frame ID:  668
# frame ID:  669
# frame ID:  670
# frame ID:  671
# frame ID:  672
# frame ID:  673
# frame ID:  674
# frame ID:  675
# frame ID:  676
# frame ID:  677
# frame ID:  678
# frame ID:  679
# frame ID:  680
# frame ID:  681
# frame ID:  682
# frame ID:  683
# frame ID:  684
# frame ID:  685
# frame ID:  686
# frame ID:  687
# frame ID:  688
# frame ID:  689
# frame ID:  690
# frame ID:  691
# frame ID:  692
# frame ID:  693
# frame ID:  694
# frame ID:  695
# frame ID:  696
# frame ID:  697
# frame ID:  698
# frame ID:  699
# frame ID:  700
# frame ID:  701
# frame ID:  702
# frame ID:  703
# frame ID:  704
# frame ID:  705
# frame ID:  706
# frame ID:  707
# frame ID:  708
# frame ID:  709
# washing time:  16.624999999999925
# frame ID:  710
# washing time:  16.666666666666593
# frame ID:  711
# washing time:  16.70833333333326
# frame ID:  712
# washing time:  16.74999999999993
# frame ID:  713
# washing time:  16.791666666666597
# frame ID:  714
# washing time:  16.833333333333265
# frame ID:  715
# washing time:  16.874999999999932
# frame ID:  716
# washing time:  16.9166666666666
# frame ID:  717
# washing time:  16.958333333333268
# frame ID:  718
# washing time:  16.999999999999936
# frame ID:  719
# washing time:  17.041666666666604
# frame ID:  720
# washing time:  17.08333333333327
# frame ID:  721
# washing time:  17.12499999999994
# frame ID:  722
# washing time:  17.166666666666607
# frame ID:  723
# frame ID:  724
# frame ID:  725
# frame ID:  726
# washing time:  17.208333333333275
# frame ID:  727
# washing time:  17.249999999999943
# frame ID:  728
# washing time:  17.29166666666661
# frame ID:  729
# washing time:  17.33333333333328
# frame ID:  730
# washing time:  17.374999999999947
# frame ID:  731
# washing time:  17.416666666666615
# frame ID:  732
# washing time:  17.458333333333282
# frame ID:  733
# washing time:  17.49999999999995
# frame ID:  734
# washing time:  17.541666666666618
# frame ID:  735
# washing time:  17.583333333333286
# frame ID:  736
# washing time:  17.624999999999954
# frame ID:  737
# washing time:  17.66666666666662
# frame ID:  738
# washing time:  17.70833333333329
# frame ID:  739
# washing time:  17.749999999999957
# frame ID:  740
# washing time:  17.791666666666625
# frame ID:  741
# washing time:  17.833333333333293
# frame ID:  742
# washing time:  17.87499999999996
# frame ID:  743
# washing time:  17.91666666666663
# frame ID:  744
# washing time:  17.958333333333297
# frame ID:  745
# washing time:  17.999999999999964
# frame ID:  746
# washing time:  18.041666666666632
# frame ID:  747
# washing time:  18.0833333333333
# frame ID:  748
# washing time:  18.124999999999968
# frame ID:  749
# washing time:  18.166666666666636
# frame ID:  750
# washing time:  18.208333333333304
# frame ID:  751
# washing time:  18.24999999999997
# frame ID:  752
# washing time:  18.29166666666664
# frame ID:  753
# washing time:  18.333333333333307
# frame ID:  754
# washing time:  18.374999999999975
# frame ID:  755
# washing time:  18.416666666666643
# frame ID:  756
# washing time:  18.45833333333331
# frame ID:  757
# washing time:  18.49999999999998
# frame ID:  758
# washing time:  18.541666666666647
# frame ID:  759
# washing time:  18.583333333333314
# frame ID:  760
# washing time:  18.624999999999982
# frame ID:  761
# washing time:  18.66666666666665
# frame ID:  762
# washing time:  18.708333333333318
# frame ID:  763
# washing time:  18.749999999999986
# frame ID:  764
# washing time:  18.791666666666654
# frame ID:  765
# washing time:  18.83333333333332
# frame ID:  766
# washing time:  18.87499999999999
# frame ID:  767
# washing time:  18.916666666666657
# frame ID:  768
# washing time:  18.958333333333325
# frame ID:  769
# washing time:  18.999999999999993
# frame ID:  770
# washing time:  19.04166666666666
# frame ID:  771
# washing time:  19.08333333333333
# frame ID:  772
# washing time:  19.124999999999996
# frame ID:  773
# washing time:  19.166666666666664
# frame ID:  774
# washing time:  19.208333333333332
# frame ID:  775
# washing time:  19.25
# frame ID:  776
# washing time:  19.291666666666668
# frame ID:  777
# washing time:  19.333333333333336
# frame ID:  778
# washing time:  19.375000000000004
# frame ID:  779
# washing time:  19.41666666666667
# frame ID:  780
# washing time:  19.45833333333334
# frame ID:  781
# washing time:  19.500000000000007
# frame ID:  782
# washing time:  19.541666666666675
# frame ID:  783
# washing time:  19.583333333333343
# frame ID:  784
# washing time:  19.62500000000001
# frame ID:  785
# washing time:  19.66666666666668
# frame ID:  786
# washing time:  19.708333333333346
# frame ID:  787
# washing time:  19.750000000000014
# frame ID:  788
# washing time:  19.791666666666682
# frame ID:  789
# washing time:  19.83333333333335
# frame ID:  790
# washing time:  19.875000000000018
# frame ID:  791
# washing time:  19.916666666666686
# frame ID:  792
# washing time:  19.958333333333353
# frame ID:  793
# washing time:  20.00000000000002
# frame ID:  794
# washing time:  20.04166666666669
# frame ID:  795
# washing time:  20.083333333333357
# frame ID:  796
# washing time:  20.125000000000025
# frame ID:  797
# washing time:  20.166666666666693
# frame ID:  798
# washing time:  20.20833333333336
# frame ID:  799
# washing time:  20.25000000000003
# frame ID:  800
# washing time:  20.291666666666696
# frame ID:  801
# washing time:  20.333333333333364
# frame ID:  802
# washing time:  20.375000000000032
# frame ID:  803
# washing time:  20.4166666666667
# frame ID:  804
# washing time:  20.458333333333368
# frame ID:  805
# washing time:  20.500000000000036
# frame ID:  806
# washing time:  20.541666666666703
# frame ID:  807
# washing time:  20.58333333333337
# frame ID:  808
# washing time:  20.62500000000004
# frame ID:  809
# washing time:  20.666666666666707
# frame ID:  810
# washing time:  20.708333333333375
# frame ID:  811
# washing time:  20.750000000000043
# frame ID:  812
# washing time:  20.79166666666671
# frame ID:  813
# washing time:  20.83333333333338
# frame ID:  814
# washing time:  20.875000000000046
# frame ID:  815
# washing time:  20.916666666666714
# frame ID:  816
# washing time:  20.958333333333382
# frame ID:  817
# washing time:  21.00000000000005
# frame ID:  818
# washing time:  21.041666666666718
# frame ID:  819
# washing time:  21.083333333333385
# frame ID:  820
# washing time:  21.125000000000053
# frame ID:  821
# washing time:  21.16666666666672
# frame ID:  822
# washing time:  21.20833333333339
# frame ID:  823
# washing time:  21.250000000000057
# frame ID:  824
# washing time:  21.291666666666725
# frame ID:  825
# washing time:  21.333333333333393
# frame ID:  826
# washing time:  21.37500000000006
# frame ID:  827
# washing time:  21.41666666666673
# frame ID:  828
# washing time:  21.458333333333396
# frame ID:  829
# washing time:  21.500000000000064
# frame ID:  830
# washing time:  21.541666666666732
# frame ID:  831
# washing time:  21.5833333333334
# frame ID:  832
# washing time:  21.625000000000068
# frame ID:  833
# washing time:  21.666666666666735
# frame ID:  834
# washing time:  21.708333333333403
# frame ID:  835
# washing time:  21.75000000000007
# frame ID:  836
# washing time:  21.79166666666674
# frame ID:  837
# washing time:  21.833333333333407
# frame ID:  838
# washing time:  21.875000000000075
# frame ID:  839
# washing time:  21.916666666666742
# frame ID:  840
# washing time:  21.95833333333341
# frame ID:  841
# washing time:  22.000000000000078
# frame ID:  842
# washing time:  22.041666666666746
# frame ID:  843
# washing time:  22.083333333333414
# frame ID:  844
# washing time:  22.12500000000008
# frame ID:  845
# washing time:  22.16666666666675
# frame ID:  846
# washing time:  22.208333333333417
# frame ID:  847
# washing time:  22.250000000000085
# frame ID:  848
# washing time:  22.291666666666753
# frame ID:  849
# washing time:  22.33333333333342
# frame ID:  850
# washing time:  22.37500000000009
# frame ID:  851
# washing time:  22.416666666666757
# frame ID:  852
# washing time:  22.458333333333425
# frame ID:  853
# washing time:  22.500000000000092
# frame ID:  854
# washing time:  22.54166666666676
# frame ID:  855
# washing time:  22.583333333333428
# frame ID:  856
# washing time:  22.625000000000096
# frame ID:  857
# washing time:  22.666666666666764
# frame ID:  858
# washing time:  22.70833333333343
# frame ID:  859
# washing time:  22.7500000000001
# frame ID:  860
# washing time:  22.791666666666767
# frame ID:  861
# washing time:  22.833333333333435
# frame ID:  862
# washing time:  22.875000000000103
# frame ID:  863
# washing time:  22.91666666666677
# frame ID:  864
# washing time:  22.95833333333344
# frame ID:  865
# washing time:  23.000000000000107
# frame ID:  866
# washing time:  23.041666666666774
# frame ID:  867
# washing time:  23.083333333333442
# frame ID:  868
# washing time:  23.12500000000011
# frame ID:  869
# washing time:  23.166666666666778
# frame ID:  870
# washing time:  23.208333333333446
# frame ID:  871
# washing time:  23.250000000000114
# frame ID:  872
# washing time:  23.29166666666678
# frame ID:  873
# washing time:  23.33333333333345
# frame ID:  874
# washing time:  23.375000000000117
# frame ID:  875
# washing time:  23.416666666666785
# frame ID:  876
# washing time:  23.458333333333453
# frame ID:  877
# washing time:  23.50000000000012
# frame ID:  878
# washing time:  23.54166666666679
# frame ID:  879
# washing time:  23.583333333333456
# frame ID:  880
# washing time:  23.625000000000124
# frame ID:  881
# washing time:  23.666666666666792
# frame ID:  882
# washing time:  23.70833333333346
# frame ID:  883
# washing time:  23.750000000000128
# frame ID:  884
# washing time:  23.791666666666796
# frame ID:  885
# washing time:  23.833333333333464
# frame ID:  886
# washing time:  23.87500000000013
# frame ID:  887
# washing time:  23.9166666666668
# frame ID:  888
# washing time:  23.958333333333467
# frame ID:  889
# washing time:  24.000000000000135
# frame ID:  890
# washing time:  24.041666666666803
# frame ID:  891
# washing time:  24.08333333333347
# frame ID:  892
# washing time:  24.12500000000014
# frame ID:  893
# washing time:  24.166666666666806
# frame ID:  894
# washing time:  24.208333333333474
# frame ID:  895
# washing time:  24.250000000000142
# frame ID:  896
# washing time:  24.29166666666681
# frame ID:  897
# washing time:  24.333333333333478
# frame ID:  898
# washing time:  24.375000000000146
# frame ID:  899
# washing time:  24.416666666666814
# frame ID:  900
# washing time:  24.45833333333348
# frame ID:  901
# washing time:  24.50000000000015
# frame ID:  902
# washing time:  24.541666666666817
# frame ID:  903
# washing time:  24.583333333333485
# frame ID:  904
# washing time:  24.625000000000153
# frame ID:  905
# washing time:  24.66666666666682
# frame ID:  906
# washing time:  24.70833333333349
# frame ID:  907
# washing time:  24.750000000000156
# frame ID:  908
# washing time:  24.791666666666824
# frame ID:  909
# washing time:  24.833333333333492
# frame ID:  910
# washing time:  24.87500000000016
# frame ID:  911
# washing time:  24.916666666666828
# frame ID:  912
# washing time:  24.958333333333496
# frame ID:  913
# washing time:  25.000000000000163
# frame ID:  914
# washing time:  25.04166666666683
# frame ID:  915
# washing time:  25.0833333333335
# frame ID:  916
# washing time:  25.125000000000167
# frame ID:  917
# washing time:  25.166666666666835
# frame ID:  918
# washing time:  25.208333333333503
# frame ID:  919
# washing time:  25.25000000000017
# frame ID:  920
# washing time:  25.29166666666684
# frame ID:  921
# washing time:  25.333333333333506
# frame ID:  922
# washing time:  25.375000000000174
# frame ID:  923
# washing time:  25.416666666666842
# frame ID:  924
# washing time:  25.45833333333351
# frame ID:  925
# washing time:  25.500000000000178
# frame ID:  926
# washing time:  25.541666666666845
# frame ID:  927
# washing time:  25.583333333333513
# frame ID:  928
# washing time:  25.62500000000018
# frame ID:  929
# washing time:  25.66666666666685
# frame ID:  930
# washing time:  25.708333333333517
# frame ID:  931
# washing time:  25.750000000000185
# frame ID:  932
# washing time:  25.791666666666853
# frame ID:  933
# washing time:  25.83333333333352
# frame ID:  934
# washing time:  25.87500000000019
# frame ID:  935
# washing time:  25.916666666666856
# frame ID:  936
# washing time:  25.958333333333524
# frame ID:  937
# washing time:  26.000000000000192
# frame ID:  938
# washing time:  26.04166666666686
# frame ID:  939
# washing time:  26.083333333333528
# frame ID:  940
# washing time:  26.125000000000195
# frame ID:  941
# washing time:  26.166666666666863
# frame ID:  942
# washing time:  26.20833333333353
# frame ID:  943
# washing time:  26.2500000000002
# frame ID:  944
# washing time:  26.291666666666867
# frame ID:  945
# washing time:  26.333333333333535
# frame ID:  946
# washing time:  26.375000000000203
# frame ID:  947
# washing time:  26.41666666666687
# frame ID:  948
# washing time:  26.458333333333538
# frame ID:  949
# washing time:  26.500000000000206
# frame ID:  950
# washing time:  26.541666666666874
# frame ID:  951
# washing time:  26.58333333333354
# frame ID:  952
# washing time:  26.62500000000021
# frame ID:  953
# washing time:  26.666666666666877
# frame ID:  954
# washing time:  26.708333333333545
# frame ID:  955
# washing time:  26.750000000000213
# frame ID:  956
# washing time:  26.79166666666688
# frame ID:  957
# washing time:  26.83333333333355
# frame ID:  958
# washing time:  26.875000000000217
# frame ID:  959
# washing time:  26.916666666666885
# frame ID:  960
# washing time:  26.958333333333552
# frame ID:  961
# washing time:  27.00000000000022
# frame ID:  962
# washing time:  27.041666666666888
# frame ID:  963
# washing time:  27.083333333333556
# frame ID:  964
# washing time:  27.125000000000224
# frame ID:  965
# washing time:  27.16666666666689
# frame ID:  966
# washing time:  27.20833333333356
# frame ID:  967
# washing time:  27.250000000000227
# frame ID:  968
# washing time:  27.291666666666895
# frame ID:  969
# washing time:  27.333333333333563
# frame ID:  970
# washing time:  27.37500000000023
# frame ID:  971
# washing time:  27.4166666666669
# frame ID:  972
# washing time:  27.458333333333567
# frame ID:  973
# washing time:  27.500000000000234
# frame ID:  974
# washing time:  27.541666666666902
# frame ID:  975
# washing time:  27.58333333333357
# frame ID:  976
# washing time:  27.625000000000238
# frame ID:  977
# washing time:  27.666666666666906
# frame ID:  978
# washing time:  27.708333333333574
# frame ID:  979
# washing time:  27.75000000000024
# frame ID:  980
# washing time:  27.79166666666691
# frame ID:  981
# washing time:  27.833333333333577
# frame ID:  982
# washing time:  27.875000000000245
# frame ID:  983
# washing time:  27.916666666666913
# frame ID:  984
# washing time:  27.95833333333358
# frame ID:  985
# washing time:  28.00000000000025
# frame ID:  986
# washing time:  28.041666666666917
# frame ID:  987
# washing time:  28.083333333333584
# frame ID:  988
# washing time:  28.125000000000252
# frame ID:  989
# washing time:  28.16666666666692
# frame ID:  990
# washing time:  28.208333333333588
# frame ID:  991
# washing time:  28.250000000000256
# frame ID:  992
# washing time:  28.291666666666924
# frame ID:  993
# washing time:  28.33333333333359
# frame ID:  994
# washing time:  28.37500000000026
# frame ID:  995
# washing time:  28.416666666666927
# frame ID:  996
# washing time:  28.458333333333595
# frame ID:  997
# washing time:  28.500000000000263
# frame ID:  998
# washing time:  28.54166666666693
# frame ID:  999
# washing time:  28.5833333333336
# frame ID:  1000
# washing time:  28.625000000000266
# frame ID:  1001
# washing time:  28.666666666666934
# frame ID:  1002
# washing time:  28.708333333333602
# frame ID:  1003
# washing time:  28.75000000000027
# frame ID:  1004
# washing time:  28.791666666666938
# frame ID:  1005
# washing time:  28.833333333333606
# frame ID:  1006
# washing time:  28.875000000000274
# frame ID:  1007
# washing time:  28.91666666666694
# frame ID:  1008
# washing time:  28.95833333333361
# frame ID:  1009
# washing time:  29.000000000000277
# frame ID:  1010
# washing time:  29.041666666666945
# frame ID:  1011
# washing time:  29.083333333333613
# frame ID:  1012
# washing time:  29.12500000000028
# frame ID:  1013
# washing time:  29.16666666666695
# frame ID:  1014
# washing time:  29.208333333333616
# frame ID:  1015
# washing time:  29.250000000000284
# frame ID:  1016
# washing time:  29.291666666666952
# frame ID:  1017
# washing time:  29.33333333333362
# frame ID:  1018
# washing time:  29.375000000000288
# frame ID:  1019
# washing time:  29.416666666666956
# frame ID:  1020
# washing time:  29.458333333333623
# frame ID:  1021
# washing time:  29.50000000000029
# frame ID:  1022
# washing time:  29.54166666666696
# frame ID:  1023
# washing time:  29.583333333333627
# frame ID:  1024
# washing time:  29.625000000000295
# frame ID:  1025
# washing time:  29.666666666666963
# frame ID:  1026
# washing time:  29.70833333333363
# frame ID:  1027
# washing time:  29.7500000000003
# frame ID:  1028
# washing time:  29.791666666666966
# frame ID:  1029
# washing time:  29.833333333333634
# frame ID:  1030
# washing time:  29.875000000000302
# frame ID:  1031
# washing time:  29.91666666666697
# frame ID:  1032
# washing time:  29.958333333333638
# frame ID:  1033
# washing time:  30.000000000000306
# frame ID:  1034
# washing time:  30.041666666666973
# frame ID:  1035
# washing time:  30.08333333333364
# frame ID:  1036
# washing time:  30.12500000000031
# frame ID:  1037
# washing time:  30.166666666666977
# frame ID:  1038
# washing time:  30.208333333333645
# frame ID:  1039
# washing time:  30.250000000000313
# frame ID:  1040
# washing time:  30.29166666666698
# frame ID:  1041
# washing time:  30.33333333333365
# frame ID:  1042
# washing time:  30.375000000000316
# frame ID:  1043
# washing time:  30.416666666666984
# frame ID:  1044
# washing time:  30.458333333333652
# frame ID:  1045
# washing time:  30.50000000000032
# frame ID:  1046
# washing time:  30.541666666666988
# frame ID:  1047
# washing time:  30.583333333333655
# frame ID:  1048
# washing time:  30.625000000000323
# frame ID:  1049
# washing time:  30.66666666666699
# frame ID:  1050
# washing time:  30.70833333333366
# frame ID:  1051
# washing time:  30.750000000000327
# frame ID:  1052
# washing time:  30.791666666666995
# frame ID:  1053
# washing time:  30.833333333333663
# frame ID:  1054
# washing time:  30.87500000000033
# frame ID:  1055
# washing time:  30.916666666667
# frame ID:  1056
# washing time:  30.958333333333666
# frame ID:  1057
# washing time:  31.000000000000334
# frame ID:  1058
# washing time:  31.041666666667002
# frame ID:  1059
# washing time:  31.08333333333367
# frame ID:  1060
# washing time:  31.125000000000338
# frame ID:  1061
# washing time:  31.166666666667005
# frame ID:  1062
# washing time:  31.208333333333673
# frame ID:  1063
# washing time:  31.25000000000034
# frame ID:  1064
# washing time:  31.29166666666701
# frame ID:  1065
# washing time:  31.333333333333677
# frame ID:  1066
# washing time:  31.375000000000345
# frame ID:  1067
# washing time:  31.416666666667012
# frame ID:  1068
# frame ID:  1069
# washing time:  31.45833333333368
# frame ID:  1070
# frame ID:  1071
# frame ID:  1072
# frame ID:  1073
# frame ID:  1074
# frame ID:  1075
# frame ID:  1076
# frame ID:  1077
# frame ID:  1078
# frame ID:  1079
# frame ID:  1080
# frame ID:  1081
# frame ID:  1082
# frame ID:  1083
# frame ID:  1084
# frame ID:  1085
# frame ID:  1086
# frame ID:  1087
# frame ID:  1088
# frame ID:  1089
# frame ID:  1090
# frame ID:  1091
# frame ID:  1092
# frame ID:  1093
# frame ID:  1094
# frame ID:  1095
# frame ID:  1096
# frame ID:  1097
# frame ID:  1098
# frame ID:  1099
# frame ID:  1100
# frame ID:  1101
# frame ID:  1102
# frame ID:  1103
# frame ID:  1104
# frame ID:  1105
# frame ID:  1106
# frame ID:  1107
# frame ID:  1108
# frame ID:  1109
# frame ID:  1110
